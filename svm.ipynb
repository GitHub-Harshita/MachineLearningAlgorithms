# %% [markdown]
# <a href="https://colab.research.google.com/github/GitHub-Harshita/MachineLearningAlgorithms/blob/main/svm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.svm import SVC
import matplotlib.pyplot as plt

# Features: [study_hours, sleep_hours]
X = np.array([
    [1, 5],   # fail
    [2, 6],   # fail
    [2, 4],   # fail
    [3, 5],   # fail
    [5, 7],   # pass
    [6, 8],   # pass
    [7, 6],   # pass
    [8, 7]    # pass
])

# Labels: 0 = Fail, 1 = Pass
y = np.array([0, 0, 0, 0, 1, 1, 1, 1])

# %%
model = SVC(kernel='linear')
model.fit(X, y)
# Out:
# SVC(kernel='linear')

# %%
# New student
new_student = [[4, 6]]

prediction = model.predict(new_student)

if prediction[0] == 1:
    print("Student will PASS")
else:
    print("Student will FAIL")
# Out:
# Student will PASS

# %%
plt.scatter(X[:,0], X[:,1], c=y, cmap='bwr')

plt.xlabel("Study Hours")
plt.ylabel("Sleep Hours")
plt.title("SVM: Pass vs Fail")

plt.show()

# %%
plt.scatter(X[:,0], X[:,1], c=y, cmap='bwr', s=80)

# ---- PLOT DECISION BOUNDARY ----
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

# create grid
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T

# decision function
Z = model.decision_function(xy).reshape(XX.shape)

# plot boundary line
ax.contour(XX, YY, Z, levels=[0])

plt.xlabel("Study Hours")
plt.ylabel("Sleep Hours")
plt.title("SVM Decision Boundary")

plt.show()
